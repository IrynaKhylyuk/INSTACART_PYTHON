# %% [markdown]
# # Part 1 Customer data set preparation and combining with rest data

# %% [markdown]
# 1. Import libraries and customer data set
# 2. Exploratory data analysis
# 3. Data Wrangling
#
# 3.1. Dropping columns
# 3.2. Renaming columns
# 3.3. Changing data type
#
# 4. Data consistency check
#
# 4.1. Checking mixed data types
# 4.2. Missing data
# 4.3. Duplicates
#
# 5. Combining customer data set with ords_prods_merge data
# 6. Export ords_prods_all dataset en pkl

# %% [markdown]
# # 1. Import libraries and customer data set

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Create path
path = r"C:\Users\irikh\iCloudDrive\Data analytics\Instacart basket Analysis"

# %%
# Import data set
df_customers = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'), index_col = False)

# %% [markdown]
# # 2. Exploratory data analysis

# %%
df_customers.head ()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
df_customers.tail ()
# Out:
#         user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 206204   168073       Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095       Rose   Rollins  Female      California   27    4/1/2020
# 206208    80148    Cynthia     Noble  Female        New York   55    4/1/2020
#
#         n_dependants fam_status  income
# 206204             1    married  148828
# 206205             3    married  168639
# 206206             2    married   53374
# 206207             1    married   99799
# 206208             1    married   57095

# %%
df_customers.shape
# Out:
# (206209, 10)

# %%
df_customers.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       206209 non-null  int64
#  1   First Name    194950 non-null  object
#  2   Surnam        206209 non-null  object
#  3   Gender        206209 non-null  object
#  4   STATE         206209 non-null  object
#  5   Age           206209 non-null  int64
#  6   date_joined   206209 non-null  object
#  7   n_dependants  206209 non-null  int64
#  8   fam_status    206209 non-null  object
#  9   income        206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %% [markdown]
# # 3. Data Wrangling

# %% [markdown]
# ## 3.1. Dropping columns

# %% [markdown]
# ### No dropping columns

# %% [markdown]
# ## 3.2. Renaming columns

# %%
# Renaming columns
df_customers.rename(columns = {'Surnam' : 'Surname','STATE' : 'US state','n_dependants' : 'number_of_dependants','fam_status' : 'marital_status'}, inplace = True)

# %%
# Checking result
df_customers.columns
# Out:
# Index(['user_id', 'First Name', 'Surname', 'Gender', 'US state', 'Age',
#        'date_joined', 'number_of_dependants', 'marital_status', 'income'],
#       dtype='object')

# %% [markdown]
# ## 3.3. Changing data type

# %%
# Checking data type
df_customers.dtypes
# Out:
# user_id                  int64
# First Name              object
# Surname                 object
# Gender                  object
# US state                object
# Age                      int64
# date_joined             object
# number_of_dependants     int64
# marital_status          object
# income                   int64
# dtype: object

# %% [markdown]
# # 4. Data consistency check

# %%
# General statistic data view
df_customers.describe ()
# Out:
#              user_id            Age  number_of_dependants         income
# count  206209.000000  206209.000000         206209.000000  206209.000000
# mean   103105.000000      49.501646              1.499823   94632.852548
# std     59527.555167      18.480962              1.118433   42473.786988
# min         1.000000      18.000000              0.000000   25903.000000
# 25%     51553.000000      33.000000              0.000000   59874.000000
# 50%    103105.000000      49.000000              1.000000   93547.000000
# 75%    154657.000000      66.000000              3.000000  124244.000000
# max    206209.000000      81.000000              3.000000  593901.000000

# %% [markdown]
# ## 4.1. Checking mixed data types

# %%
# Checking data for mix data type
for col in df_customers.columns.tolist():
  weird = (df_customers[[col]].applymap(type) != df_customers[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_customers[weird]) > 0:
    print (col, ' mixed')
  else: print (col, ' consistent')
# Out:
# user_id  consistent
# First Name  mixed
# Surname  consistent
# Gender  consistent
# US state  consistent
# Age  consistent
# date_joined  consistent
# number_of_dependants  consistent
# marital_status  consistent
# income  consistent

# %%
# Changing mixed datatype 
df_customers['First Name'] = df_customers['First Name'].astype('str')

# %%
# Checking result
for col in df_customers.columns.tolist():
  weird = (df_customers[[col]].applymap(type) != df_customers[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_customers[weird]) > 0:
    print (col, ' mixed')
  else: print (col, ' consistent')
# Out:
# user_id  consistent
# First Name  consistent
# Surname  consistent
# Gender  consistent
# US state  consistent
# Age  consistent
# date_joined  consistent
# number_of_dependants  consistent
# marital_status  consistent
# income  consistent

# %% [markdown]
# ## 4.2. Missing data

# %%
# Finding missing value 
df_customers.isnull().sum()
# Out:
# user_id                 0
# First Name              0
# Surname                 0
# Gender                  0
# US state                0
# Age                     0
# date_joined             0
# number_of_dependants    0
# marital_status          0
# income                  0
# dtype: int64

# %% [markdown]
# ## 4.3. Duplicates

# %%
# Finding duplicates by creating subset 
df_dups = df_customers[df_customers.duplicated ()]

# %%
# Checking result (subset) 
df_dups
# Out:
# Empty DataFrame
# Columns: [user_id, First Name, Surname, Gender, US state, Age, date_joined, number_of_dependants, marital_status, income]
# Index: []

# %% [markdown]
# # 5. Combining customer data set with ords_prods_merge data

# %%
# Import ords_prods_merge.pkl data
df_ords_prods_merge = pd.read_pickle(r'C:\Users\irikh\iCloudDrive\Data analytics\Instacart basket Analysis\02 Data\Prepared Data\ords_prods_merge.pkl')

# %%
# Checking data after importing
df_ords_prods_merge.head (10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN       196.0                1.0        0.0
# 1                   15.0       196.0                1.0        1.0
# 2                   21.0       196.0                1.0        1.0
# 3                   29.0       196.0                1.0        1.0
# 4                   28.0       196.0                1.0        1.0
# 5                   19.0       196.0                1.0        1.0
# 6                   20.0       196.0                1.0        1.0
# 7                   14.0       196.0                2.0        1.0
# 8                    0.0       196.0                4.0        1.0
# 9                   30.0       196.0                1.0        1.0
#
#   product_name  ...    price_range_loc     busiest_day    busiest_days  \
# 0         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 1         Soda  ...  Mid-range product  Regularly busy      Least busy
# 2         Soda  ...  Mid-range product  Regularly busy      Least busy
# 3         Soda  ...  Mid-range product      Least busy      Least busy
# 4         Soda  ...  Mid-range product      Least busy      Least busy
# 5         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 6         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 7         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 8         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 9         Soda  ...  Mid-range product      Least busy      Least busy
#
#   busiest_period_of_day max_order  loyalty_flag mean_price spending_flag  \
# 0        Regularly busy        10  New customer   6.367797   Low spender
# 1        Regularly busy        10  New customer   6.367797   Low spender
# 2           Most orders        10  New customer   6.367797   Low spender
# 3        Regularly busy        10  New customer   6.367797   Low spender
# 4           Most orders        10  New customer   6.367797   Low spender
# 5        Regularly busy        10  New customer   6.367797   Low spender
# 6           Most orders        10  New customer   6.367797   Low spender
# 7           Most orders        10  New customer   6.367797   Low spender
# 8           Most orders        10  New customer   6.367797   Low spender
# 9        Regularly busy        10  New customer   6.367797   Low spender
#
#    median_frequency         frequency_flag
# 0              20.5  Non-frequent customer
# 1              20.5  Non-frequent customer
# 2              20.5  Non-frequent customer
# 3              20.5  Non-frequent customer
# 4              20.5  Non-frequent customer
# 5              20.5  Non-frequent customer
# 6              20.5  Non-frequent customer
# 7              20.5  Non-frequent customer
# 8              20.5  Non-frequent customer
# 9              20.5  Non-frequent customer
#
# [10 rows x 24 columns]

# %%
# Checking data after importing
df_ords_prods_merge.tail (10)
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 32404849    576295   202557            12                   3
# 32404850    960088   202557            13                   4
# 32404851    343962   202557            14                   0
# 32404852   2329472   202557            15                   6
# 32404853    694731   202557            16                   1
# 32404854   1320836   202557            17                   2
# 32404855     31526   202557            18                   5
# 32404856    758936   203436             1                   2
# 32404857   2745165   203436             2                   3
# 32404858   3093936   205420             1                   4
#
#           order_hour_of_day  days_since_last_order  product_id  \
# 32404849                 10                   11.0     43553.0
# 32404850                 12                   15.0     43553.0
# 32404851                 10                    3.0     43553.0
# 32404852                 12                    6.0     43553.0
# 32404853                 14                    2.0     43553.0
# 32404854                 15                    1.0     43553.0
# 32404855                 11                    3.0     43553.0
# 32404856                  7                    NaN     42338.0
# 32404857                  5                   15.0     42338.0
# 32404858                 14                    NaN     28818.0
#
#           add_to_cart_order  reordered                   product_name  ...  \
# 32404849               14.0        1.0            Orange Energy Shots  ...
# 32404850                3.0        1.0            Orange Energy Shots  ...
# 32404851                2.0        1.0            Orange Energy Shots  ...
# 32404852                2.0        1.0            Orange Energy Shots  ...
# 32404853                2.0        1.0            Orange Energy Shots  ...
# 32404854                2.0        1.0            Orange Energy Shots  ...
# 32404855                2.0        1.0            Orange Energy Shots  ...
# 32404856                4.0        0.0          Zucchini Chips, Pesto  ...
# 32404857               16.0        1.0          Zucchini Chips, Pesto  ...
# 32404858                8.0        0.0  Hot Oatmeal Multigrain Raisin  ...
#
#             price_range_loc     busiest_day    busiest_days  \
# 32404849  Low-range product  Regularly busy      Least busy
# 32404850  Low-range product      Least busy      Least busy
# 32404851  Low-range product     Busiest day    Busiest days
# 32404852  Low-range product  Regularly busy  Regularly busy
# 32404853  Low-range product  Regularly busy    Busiest days
# 32404854  Low-range product  Regularly busy  Regularly busy
# 32404855  Low-range product  Regularly busy  Regularly busy
# 32404856  Mid-range product  Regularly busy  Regularly busy
# 32404857  Mid-range product  Regularly busy      Least busy
# 32404858  Mid-range product      Least busy      Least busy
#
#          busiest_period_of_day max_order      loyalty_flag mean_price  \
# 32404849           Most orders        31  Regular customer   6.905655
# 32404850           Most orders        31  Regular customer   6.905655
# 32404851           Most orders        31  Regular customer   6.905655
# 32404852           Most orders        31  Regular customer   6.905655
# 32404853           Most orders        31  Regular customer   6.905655
# 32404854           Most orders        31  Regular customer   6.905655
# 32404855           Most orders        31  Regular customer   6.905655
# 32404856        Regularly busy         3      New customer   7.631579
# 32404857         Fewest orders         3      New customer   7.631579
# 32404858           Most orders        16  Regular customer   7.684746
#
#          spending_flag  median_frequency     frequency_flag
# 32404849   Low spender               8.0  Frequent customer
# 32404850   Low spender               8.0  Frequent customer
# 32404851   Low spender               8.0  Frequent customer
# 32404852   Low spender               8.0  Frequent customer
# 32404853   Low spender               8.0  Frequent customer
# 32404854   Low spender               8.0  Frequent customer
# 32404855   Low spender               8.0  Frequent customer
# 32404856   Low spender              15.0   Regular customer
# 32404857   Low spender              15.0   Regular customer
# 32404858   Low spender              13.0   Regular customer
#
# [10 rows x 24 columns]

# %%
# Checking data type of key columns before merging
df_ords_prods_merge["user_id"].dtype
# Out:
# dtype('int64')

# %%
# Checking ords_prods_merge data before merging  
df_ords_prods_merge.shape
# Out:
# (32404859, 24)

# %%
# Checking customer data before merging  
df_customers.shape
# Out:
# (206209, 10)

# %%
# Delete merge flag for next merge
del df_ords_prods_merge['_merge']

# %%
# Merging customer data set with main using key user_id
df_ords_prods_all = df_ords_prods_merge.merge (df_customers, on = 'user_id', indicator = True)

# %%
# Confirm the merge using the merge flag (inner)
df_ords_prods_all['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# Confirm the merge using the merge flag (outer)
df_ords_prods_all['_merge'].value_counts(dropna = False)
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# Checking new data columns after merging
df_ords_prods_all.head(30)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2539329        1             1                   2                  8
# 11   2539329        1             1                   2                  8
# 12   2398795        1             2                   3                  7
# 13    473747        1             3                   3                 12
# 14   2254736        1             4                   4                  7
# 15    431534        1             5                   4                 15
# 16   3367565        1             6                   2                  7
# 17    550135        1             7                   1                  9
# 18   3108588        1             8                   1                 14
# 19   2295261        1             9                   1                 16
# 20   2550362        1            10                   4                  8
# 21   2539329        1             1                   2                  8
# 22   2398795        1             2                   3                  7
# 23   2539329        1             1                   2                  8
# 24   2254736        1             4                   4                  7
# 25   2398795        1             2                   3                  7
# 26    473747        1             3                   3                 12
# 27   2254736        1             4                   4                  7
# 28    431534        1             5                   4                 15
# 29   3367565        1             6                   2                  7
#
#     days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN       196.0                1.0        0.0
# 1                    15.0       196.0                1.0        1.0
# 2                    21.0       196.0                1.0        1.0
# 3                    29.0       196.0                1.0        1.0
# 4                    28.0       196.0                1.0        1.0
# 5                    19.0       196.0                1.0        1.0
# 6                    20.0       196.0                1.0        1.0
# 7                    14.0       196.0                2.0        1.0
# 8                     0.0       196.0                4.0        1.0
# 9                    30.0       196.0                1.0        1.0
# 10                    NaN     14084.0                2.0        0.0
# 11                    NaN     12427.0                3.0        0.0
# 12                   15.0     12427.0                3.0        1.0
# 13                   21.0     12427.0                2.0        1.0
# 14                   29.0     12427.0                2.0        1.0
# 15                   28.0     12427.0                2.0        1.0
# 16                   19.0     12427.0                2.0        1.0
# 17                   20.0     12427.0                3.0        1.0
# 18                   14.0     12427.0                1.0        1.0
# 19                    0.0     12427.0                6.0        1.0
# 20                   30.0     12427.0                9.0        1.0
# 21                    NaN     26088.0                4.0        0.0
# 22                   15.0     26088.0                5.0        1.0
# 23                    NaN     26405.0                5.0        0.0
# 24                   29.0     26405.0                5.0        1.0
# 25                   15.0     10258.0                2.0        0.0
# 26                   21.0     10258.0                3.0        1.0
# 27                   29.0     10258.0                3.0        1.0
# 28                   28.0     10258.0                3.0        1.0
# 29                   19.0     10258.0                3.0        1.0
#
#                                product_name  ...  First Name  Surname  Gender  \
# 0                                      Soda  ...       Linda   Nguyen  Female
# 1                                      Soda  ...       Linda   Nguyen  Female
# 2                                      Soda  ...       Linda   Nguyen  Female
# 3                                      Soda  ...       Linda   Nguyen  Female
# 4                                      Soda  ...       Linda   Nguyen  Female
# 5                                      Soda  ...       Linda   Nguyen  Female
# 6                                      Soda  ...       Linda   Nguyen  Female
# 7                                      Soda  ...       Linda   Nguyen  Female
# 8                                      Soda  ...       Linda   Nguyen  Female
# 9                                      Soda  ...       Linda   Nguyen  Female
# 10  Organic Unsweetened Vanilla Almond Milk  ...       Linda   Nguyen  Female
# 11                      Original Beef Jerky  ...       Linda   Nguyen  Female
# 12                      Original Beef Jerky  ...       Linda   Nguyen  Female
# 13                      Original Beef Jerky  ...       Linda   Nguyen  Female
# 14                      Original Beef Jerky  ...       Linda   Nguyen  Female
# 15                      Original Beef Jerky  ...       Linda   Nguyen  Female
# 16                      Original Beef Jerky  ...       Linda   Nguyen  Female
# 17                      Original Beef Jerky  ...       Linda   Nguyen  Female
# 18                      Original Beef Jerky  ...       Linda   Nguyen  Female
# 19                      Original Beef Jerky  ...       Linda   Nguyen  Female
# 20                      Original Beef Jerky  ...       Linda   Nguyen  Female
# 21               Aged White Cheddar Popcorn  ...       Linda   Nguyen  Female
# 22               Aged White Cheddar Popcorn  ...       Linda   Nguyen  Female
# 23         XL Pick-A-Size Paper Towel Rolls  ...       Linda   Nguyen  Female
# 24         XL Pick-A-Size Paper Towel Rolls  ...       Linda   Nguyen  Female
# 25                               Pistachios  ...       Linda   Nguyen  Female
# 26                               Pistachios  ...       Linda   Nguyen  Female
# 27                               Pistachios  ...       Linda   Nguyen  Female
# 28                               Pistachios  ...       Linda   Nguyen  Female
# 29                               Pistachios  ...       Linda   Nguyen  Female
#
#    US state Age date_joined number_of_dependants  marital_status income  \
# 0   Alabama  31   2/17/2019                    3         married  40423
# 1   Alabama  31   2/17/2019                    3         married  40423
# 2   Alabama  31   2/17/2019                    3         married  40423
# 3   Alabama  31   2/17/2019                    3         married  40423
# 4   Alabama  31   2/17/2019                    3         married  40423
# 5   Alabama  31   2/17/2019                    3         married  40423
# 6   Alabama  31   2/17/2019                    3         married  40423
# 7   Alabama  31   2/17/2019                    3         married  40423
# 8   Alabama  31   2/17/2019                    3         married  40423
# 9   Alabama  31   2/17/2019                    3         married  40423
# 10  Alabama  31   2/17/2019                    3         married  40423
# 11  Alabama  31   2/17/2019                    3         married  40423
# 12  Alabama  31   2/17/2019                    3         married  40423
# 13  Alabama  31   2/17/2019                    3         married  40423
# 14  Alabama  31   2/17/2019                    3         married  40423
# 15  Alabama  31   2/17/2019                    3         married  40423
# 16  Alabama  31   2/17/2019                    3         married  40423
# 17  Alabama  31   2/17/2019                    3         married  40423
# 18  Alabama  31   2/17/2019                    3         married  40423
# 19  Alabama  31   2/17/2019                    3         married  40423
# 20  Alabama  31   2/17/2019                    3         married  40423
# 21  Alabama  31   2/17/2019                    3         married  40423
# 22  Alabama  31   2/17/2019                    3         married  40423
# 23  Alabama  31   2/17/2019                    3         married  40423
# 24  Alabama  31   2/17/2019                    3         married  40423
# 25  Alabama  31   2/17/2019                    3         married  40423
# 26  Alabama  31   2/17/2019                    3         married  40423
# 27  Alabama  31   2/17/2019                    3         married  40423
# 28  Alabama  31   2/17/2019                    3         married  40423
# 29  Alabama  31   2/17/2019                    3         married  40423
#
#     _merge
# 0     both
# 1     both
# 2     both
# 3     both
# 4     both
# 5     both
# 6     both
# 7     both
# 8     both
# 9     both
# 10    both
# 11    both
# 12    both
# 13    both
# 14    both
# 15    both
# 16    both
# 17    both
# 18    both
# 19    both
# 20    both
# 21    both
# 22    both
# 23    both
# 24    both
# 25    both
# 26    both
# 27    both
# 28    both
# 29    both
#
# [30 rows x 33 columns]

# %%
# Checking data shape after merging
df_ords_prods_all.shape
# Out:
# (32404859, 33)

# %% [markdown]
# # 6. Export ords_prods_all dataset en pkl

# %%
# Export data in PKl
df_ords_prods_all.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_all.pkl'))
